# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of 2,00 random latitudes and longitudes 
lats = np.random.uniform(low=-90.000, size=2000)
lngs = np.random.uniform(low=-180.00, size=2000)
lats_lngs = zip (lats, lngs)

# %%
# Get the nearest city
coordinates = list(lats_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 230

# %%
# API call to weather map
import requests
from config import weather_api_key
from datetime import datetime 

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retreive information
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bahia blanca
# Processing Record 2 of Set 1 | mozarlandia
# Processing Record 3 of Set 1 | avera
# Processing Record 4 of Set 1 | san miguel
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | nueve de julio
# Processing Record 8 of Set 1 | zorritos
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | cabedelo
# Processing Record 17 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 1 | touros
# Processing Record 22 of Set 1 | port-gentil
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | caravelas
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 1 | cristalina
# Processing Record 29 of Set 1 | rio grande
# Processing Record 30 of Set 1 | guaiba
# Processing Record 31 of Set 1 | tucuman
# Processing Record 32 of Set 1 | altamira
# Processing Record 33 of Set 1 | viedma
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | saldanha
# Processing Record 36 of Set 1 | antofagasta
# Processing Record 37 of Set 1 | huarmey
# Processing Record 38 of Set 1 | vila velha
# Processing Record 39 of Set 1 | imbituba
# Processing Record 40 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 1 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 1 | faanui
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | axim
# Processing Record 46 of Set 1 | sao joao da barra
# Processing Record 47 of Set 1 | ancud
# Processing Record 48 of Set 1 | tautira
# Processing Record 49 of Set 1 | alofi
# Processing Record 50 of Set 1 | monrovia
# Processing Record 1 of Set 2 | cacu
# Processing Record 2 of Set 2 | juruti
# Processing Record 3 of Set 2 | sao felix do xingu
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | coquimbo
# Processing Record 6 of Set 2 | coihaique
# Processing Record 7 of Set 2 | pisco
# Processing Record 8 of Set 2 | machali
# Processing Record 9 of Set 2 | itupiranga
# Processing Record 10 of Set 2 | sao lourenco do sul
# Processing Record 11 of Set 2 | san cristobal
# Processing Record 12 of Set 2 | olinda
# Processing Record 13 of Set 2 | posse
# Processing Record 14 of Set 2 | torata
# Processing Record 15 of Set 2 | boa vista
# Processing Record 16 of Set 2 | tucurui
# Processing Record 17 of Set 2 | luderitz
# Processing Record 18 of Set 2 | rocha
# Processing Record 19 of Set 2 | necochea
# Processing Record 20 of Set 2 | pangai
# Processing Record 21 of Set 2 | tres arroyos
# Processing Record 22 of Set 2 | caiaponia
# Processing Record 23 of Set 2 | ilhabela
# Processing Record 24 of Set 2 | mocajuba
# Processing Record 25 of Set 2 | comodoro rivadavia
# Processing Record 26 of Set 2 | los angeles
# Processing Record 27 of Set 2 | tamandare
# Processing Record 28 of Set 2 | laguna
# Processing Record 29 of Set 2 | santa rosa
# Processing Record 30 of Set 2 | trelew
# Processing Record 31 of Set 2 | baiao
# Processing Record 32 of Set 2 | puerto madryn
# Processing Record 33 of Set 2 | bage
# Processing Record 34 of Set 2 | itaueira
# Processing Record 35 of Set 2 | miracema do tocantins
# Processing Record 36 of Set 2 | pirapora
# Processing Record 37 of Set 2 | belmonte
# Processing Record 38 of Set 2 | fare
# Processing Record 39 of Set 2 | mayor pablo lagerenza
# Processing Record 40 of Set 2 | puerto leguizamo
# Processing Record 41 of Set 2 | ipixuna
# Processing Record 42 of Set 2 | san juan
# Processing Record 43 of Set 2 | sao francisco
# Processing Record 44 of Set 2 | vallenar
# Processing Record 45 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 2 | buchanan
# Processing Record 47 of Set 2 | general pico
# Processing Record 48 of Set 2 | sao jose da coroa grande
# Processing Record 49 of Set 2 | mapiri
# Processing Record 50 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 3 | palmas
# Processing Record 2 of Set 3 | itapecerica
# Processing Record 3 of Set 3 | talcahuano
# Processing Record 4 of Set 3 | pocone
# Processing Record 5 of Set 3 | braco do norte
# Processing Record 6 of Set 3 | chicama
# Processing Record 7 of Set 3 | pangoa
# Processing Record 8 of Set 3 | guiratinga
# Processing Record 9 of Set 3 | aracuai
# Processing Record 10 of Set 3 | santa vitoria do palmar
# Processing Record 11 of Set 3 | conde
# Processing Record 12 of Set 3 | taltal
# Processing Record 13 of Set 3 | talara
# Processing Record 14 of Set 3 | navirai
# Processing Record 15 of Set 3 | barreiras
# Processing Record 16 of Set 3 | bonthe
# Processing Record 17 of Set 3 | general roca
# Processing Record 18 of Set 3 | santiago del estero
# Processing Record 19 of Set 3 | rafaela
# Processing Record 20 of Set 3 | tandil
# Processing Record 21 of Set 3 | san rafael
# Processing Record 22 of Set 3 | rio de janeiro
# Processing Record 23 of Set 3 | tucuma
# Processing Record 24 of Set 3 | pozo colorado
# Processing Record 25 of Set 3 | iquique
# Processing Record 26 of Set 3 | itu
# Processing Record 27 of Set 3 | el alto
# Processing Record 28 of Set 3 | el angel
# Processing Record 29 of Set 3 | hidrolandia
# Processing Record 30 of Set 3 | uyuni
# Processing Record 31 of Set 3 | penalva
# Processing Record 32 of Set 3 | chapadinha
# Processing Record 33 of Set 3 | tarauaca
# Processing Record 34 of Set 3 | orcopampa
# Processing Record 35 of Set 3 | maraa
# Processing Record 36 of Set 3 | arinos
# Processing Record 37 of Set 3 | santa fe do sul
# Processing Record 38 of Set 3 | san julian
# Processing Record 39 of Set 3 | guarapari
# Processing Record 40 of Set 3 | oriximina
# Processing Record 41 of Set 3 | machala
# Processing Record 42 of Set 3 | la rioja
# Processing Record 43 of Set 3 | arequipa
# Processing Record 44 of Set 3 | rio gallegos
# Processing Record 45 of Set 3 | linares
# Processing Record 46 of Set 3 | mercedes
# Processing Record 47 of Set 3 | nueva imperial
# Processing Record 48 of Set 3 | fonte boa
# Processing Record 49 of Set 3 | manacapuru
# Processing Record 50 of Set 3 | harper
# Processing Record 1 of Set 4 | constitucion
# Processing Record 2 of Set 4 | turmalina
# Processing Record 3 of Set 4 | ladario
# Processing Record 4 of Set 4 | acarau
# Processing Record 5 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 4 | requena
# Processing Record 7 of Set 4 | jacareacanga
# Processing Record 8 of Set 4 | pimentel
# Processing Record 9 of Set 4 | el carmen
# Processing Record 10 of Set 4 | trindade
# Processing Record 11 of Set 4 | manoel urbano
# Processing Record 12 of Set 4 | pimenta bueno
# Processing Record 13 of Set 4 | acari
# Processing Record 14 of Set 4 | ouro preto do oeste
# Processing Record 15 of Set 4 | vilhena
# Processing Record 16 of Set 4 | codajas
# Processing Record 17 of Set 4 | hualmay
# Processing Record 18 of Set 4 | san lorenzo
# Processing Record 19 of Set 4 | camana
# Processing Record 20 of Set 4 | trinidad
# Processing Record 21 of Set 4 | prado
# Processing Record 22 of Set 4 | tiarei
# Processing Record 23 of Set 4 | santa isabel do rio negro
# Processing Record 24 of Set 4 | tocopilla
# Processing Record 25 of Set 4 | coruripe
# Processing Record 26 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 4 | tabou
# Processing Record 28 of Set 4 | neiafu
# Processing Record 29 of Set 4 | sechura
# Processing Record 30 of Set 4 | palora
# Processing Record 31 of Set 4 | san carlos de bariloche
# Processing Record 32 of Set 4 | satipo
# Processing Record 33 of Set 4 | mumford
# Processing Record 34 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 35 of Set 4 | carauari
# Processing Record 36 of Set 4 | santa helena de goias
# Processing Record 37 of Set 4 | san ramon
# Processing Record 38 of Set 4 | iquitos
# Processing Record 39 of Set 4 | atocha
# Processing Record 40 of Set 4 | jandira
# Processing Record 41 of Set 4 | prata
# Processing Record 42 of Set 4 | osorno
# Processing Record 43 of Set 4 | sidrolandia
# Processing Record 44 of Set 4 | diamantino
# Processing Record 45 of Set 4 | aripuana
# Processing Record 46 of Set 4 | alta floresta
# Processing Record 47 of Set 4 | soure
# Processing Record 48 of Set 4 | neuquen
# Processing Record 49 of Set 4 | san patricio
# Processing Record 50 of Set 4 | tena
# Processing Record 1 of Set 5 | porto nacional
# Processing Record 2 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 3 of Set 5 | jacobina
# Processing Record 4 of Set 5 | villazon
# Processing Record 5 of Set 5 | cocachacra
# Processing Record 6 of Set 5 | itanhaem
# Processing Record 7 of Set 5 | itaituba
# Processing Record 8 of Set 5 | lano
# Processing Record 9 of Set 5 | uarini
# Processing Record 10 of Set 5 | vaitape
# Processing Record 11 of Set 5 | omboue
# Processing Record 12 of Set 5 | barreirinha
# Processing Record 13 of Set 5 | cobija
# Processing Record 14 of Set 5 | urcos
# Processing Record 15 of Set 5 | parelhas
# Processing Record 16 of Set 5 | ilo
# Processing Record 17 of Set 5 | urubicha
# Processing Record 18 of Set 5 | valparaiso
# Processing Record 19 of Set 5 | san matias
# Processing Record 20 of Set 5 | aquiraz
# Processing Record 21 of Set 5 | pitimbu
# Processing Record 22 of Set 5 | maragogi
# Processing Record 23 of Set 5 | cururupu
# Processing Record 24 of Set 5 | coahuayana
# Processing Record 25 of Set 5 | nova olimpia
# Processing Record 26 of Set 5 | rio cuarto
# Processing Record 27 of Set 5 | lircay
# Processing Record 28 of Set 5 | cambui
# Processing Record 29 of Set 5 | aracati
# Processing Record 30 of Set 5 | rolim de moura
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Bahia Blanca      AR -38.7196  -62.2724     46.72        85          69
# 1     Mozarlandia      BR -14.7447  -50.5706     71.80        31           0
# 2           Avera      US  33.1940  -82.5271     81.91        57          52
# 3      San Miguel      SV  13.4833  -88.1833     82.06        83          20
# 4         Mataura      NZ -46.1927  168.8643     47.48        98         100
# ..            ...     ...      ...       ...       ...       ...         ...
# 213  Nova Olimpia      BR -14.7972  -57.2881     73.45        37           0
# 214    Rio Cuarto      AR -33.1307  -64.3499     49.68        82         100
# 215        Lircay      PE -12.9896  -74.7205     47.08        70          34
# 216        Cambui      BR -22.6122  -46.0575     59.16        68          19
# 217       Aracati      BR  -4.5617  -37.7697     78.19        68          98
#
#      Wind Speed Current Description
# 0         10.11       broken clouds
# 1          3.98           clear sky
# 2          8.86       broken clouds
# 3          5.75          few clouds
# 4          3.13     overcast clouds
# ..          ...                 ...
# 213        3.29           clear sky
# 214       15.01     overcast clouds
# 215        1.74    scattered clouds
# 216        1.03          few clouds
# 217        8.79     overcast clouds
#
# [218 rows x 9 columns]

# %%
# Export DataFrame as CSV
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
